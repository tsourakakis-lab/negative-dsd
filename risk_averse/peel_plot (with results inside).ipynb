# %% [markdown]
# result weight and risk plots for tmdb

# %%
import numpy as np
import matplotlib.pyplot as plt

# clear

bar_width = 0.15
rho_list = [0.5,1]

tmdb_weight = {0.25:{0.5:4.294966287586544, 1:4.294966282354549, 2:3.61133769524663, 10:2.3266341924445317},
          0.5:{0.5:5.59206429401251, 1:7.456085732578475, 2:8.032458172880418, 10:0},
    1:{0.5:8.419460919302914, 1:5.415792515066372, 2:1.258269532812716, 10:0},
          2:{0.5:23.340776318398195, 1:21.715113019620027, 2:1.258269532812716, 10:0},
         3:{0.5:25.235533425218122, 1:25.2590951382019, 2:1.258269532812716, 10:0},
         4:{0.5:35.35431199248427, 1:25.347934741192194, 2:1.258269532812716, 10:0},
         5:{0.5:35.35431199248903, 1:25.347934741193882, 2:1.258269532812716, 10:0},
         6:{0.5:37.57258845195837, 1:36.33008240437453, 2:1.258269532812716, 10:0}}

tmdb_risk = {0.25:{0.5:0.6521029180037716, 1:0.6521029180037716, 2:0.3491861525791695, 10:0.19932497478773437},
        0.5:{0.5:1.118412857297549, 1:1.4912171466776294, 2:2.080999199117689, 10:0},
    1:{0.5:4.5679729447254225, 1:3.0088640078358355, 2:0.9385669960160397, 10:0},
          2:{0.5:13.859064372623102, 1:13.146549592115775, 2:0.9385669960160397, 10:0},
         3:{0.5:15.061921537821235, 1:15.16773519929054, 2:0.9385669960160397, 10:0},
         4:{0.5:20.981791076186752, 1:15.442663204889612, 2:0.9385669960160397, 10:0},
         5:{0.5:20.981791076192337, 1:15.442663204891588, 2:0.9385669960160397, 10:0},
         6:{0.5:22.308588015965995, 1:22.044078059372794, 2:0.9385669960160397, 10:0}}

tmdb_size = {0.25:{0.5:9, 1:9, 2:3, 10:7},
             0.5:{0.5:4, 1:3, 2:5, 10:1},
        1:{0.5:374, 1:1432, 2:160783, 10:1},
          2:{0.5:40, 1:48, 2:160783, 10:1},
         3:{0.5:33, 1:34, 2:160783, 10:1},
         4:{0.5:12, 1:34, 2:160783, 10:1},
         5:{0.5:12, 1:34, 2:160783, 10:1},
         6:{0.5:11, 1:12, 2:160783, 10:1}}

count = 1
# C_list = [0.25,0.5,1,2,3,4,5,6]
C_list = [1,2,3,4,5,6]
x_index = np.arange(len(C_list))
for rho in rho_list:
    C_cur_value = []
    
    for C in C_list:
        C_cur_value.append(tmdb_weight[C][rho])
    
    plt.bar(x_index+count*bar_width, C_cur_value, width=bar_width, edgecolor='black', label=r'$\lambda_1=$'+str(rho))
    count += 1
    
plt.xlabel('C')
plt.xticks( x_index + bar_width, C_list)
plt.ylabel('Average weight')
#plt.title("Average weights of outputs Tmdb risk averse peeling with C and "+r'$\lambda_1$')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig("tmdb_weight_2vals.png", bbox_inches='tight')
plt.savefig("tmdb_weight_2vals.pdf", bbox_inches='tight')
plt.show()


count = 1
for rho in rho_list:
    C_cur_value = []
    for C in C_list:
        C_cur_value.append(tmdb_risk[C][rho])
    
    plt.bar(x_index+count*bar_width, C_cur_value, width=bar_width, edgecolor='black', label=r'$\lambda_1=$'+str(rho))
    count += 1
    
    
plt.xlabel('C')
plt.xticks( x_index + bar_width, C_list)
plt.ylabel('Average risk')
#plt.title("Average risks of outputs Tmdb risk averse peeling with C and "+r'$\lambda_1$')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig("tmdb_risk_2vals.png", bbox_inches='tight')
plt.savefig("tmdb_risk_2vals.pdf", bbox_inches='tight')
plt.show()


count = 1
for rho in rho_list:
    C_cur_value = []
    for C in C_list:
        C_cur_value.append(tmdb_size[C][rho])
    
    plt.bar(x_index+count*bar_width, C_cur_value, width=bar_width, edgecolor='black', label=r'$\lambda_1=$'+str(rho))
    count += 1
    
    
plt.xlabel('C')
plt.xticks( x_index + bar_width, C_list)
plt.ylabel('Log size (base 10)')
#plt.title("Sizes of outputs Tmdb risk averse peeling with C and "+r'$\lambda_1')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig("tmdb_size_2vals.png", bbox_inches='tight')
plt.savefig("tmdb_size_2vals.pdf", bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# clear

bar_width = 0.15
rho_list = [0.5,1,2]

tmdb_weight = {0.25:{0.5:4.294966287586544, 1:4.294966282354549, 2:3.61133769524663, 10:2.3266341924445317},
          0.5:{0.5:5.59206429401251, 1:7.456085732578475, 2:8.032458172880418, 10:0},
    1:{0.5:8.419460919302914, 1:5.415792515066372, 2:1.258269532812716, 10:0},
          2:{0.5:23.340776318398195, 1:21.715113019620027, 2:1.258269532812716, 10:0},
         3:{0.5:25.235533425218122, 1:25.2590951382019, 2:1.258269532812716, 10:0},
         4:{0.5:35.35431199248427, 1:25.347934741192194, 2:1.258269532812716, 10:0},
         5:{0.5:35.35431199248903, 1:25.347934741193882, 2:1.258269532812716, 10:0},
         6:{0.5:37.57258845195837, 1:36.33008240437453, 2:1.258269532812716, 10:0}}

tmdb_risk = {0.25:{0.5:0.6521029180037716, 1:0.6521029180037716, 2:0.3491861525791695, 10:0.19932497478773437},
        0.5:{0.5:1.118412857297549, 1:1.4912171466776294, 2:2.080999199117689, 10:0},
    1:{0.5:4.5679729447254225, 1:3.0088640078358355, 2:0.9385669960160397, 10:0},
          2:{0.5:13.859064372623102, 1:13.146549592115775, 2:0.9385669960160397, 10:0},
         3:{0.5:15.061921537821235, 1:15.16773519929054, 2:0.9385669960160397, 10:0},
         4:{0.5:20.981791076186752, 1:15.442663204889612, 2:0.9385669960160397, 10:0},
         5:{0.5:20.981791076192337, 1:15.442663204891588, 2:0.9385669960160397, 10:0},
         6:{0.5:22.308588015965995, 1:22.044078059372794, 2:0.9385669960160397, 10:0}}

tmdb_size = {0.25:{0.5:9, 1:9, 2:3, 10:7},
             0.5:{0.5:4, 1:3, 2:5, 10:1},
        1:{0.5:374, 1:1432, 2:160783, 10:1},
          2:{0.5:40, 1:48, 2:160783, 10:1},
         3:{0.5:33, 1:34, 2:160783, 10:1},
         4:{0.5:12, 1:34, 2:160783, 10:1},
         5:{0.5:12, 1:34, 2:160783, 10:1},
         6:{0.5:11, 1:12, 2:160783, 10:1}}

count = 1
# C_list = [0.25,0.5,1,2,3,4,5,6]
C_list = [1,2,3,4,5,6]
x_index = np.arange(len(C_list))
for rho in rho_list:
    C_cur_value = []
    
    for C in C_list:
        C_cur_value.append(tmdb_weight[C][rho])
    
    plt.bar(x_index+count*bar_width, C_cur_value, width=bar_width, edgecolor='black', label=r'$\lambda_1=$'+str(rho))
    count += 1
    
plt.xlabel('C')
plt.xticks( x_index + bar_width, C_list)
plt.ylabel('Average weight')
#plt.title("Average weights of outputs Tmdb risk averse peeling with C and "+r'$\lambda_1$')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig("tmdb_weight.png", bbox_inches='tight')
plt.savefig("tmdb_weight.pdf", bbox_inches='tight')
plt.show()

# %%
count = 1
for rho in rho_list:
    C_cur_value = []
    for C in C_list:
        C_cur_value.append(tmdb_risk[C][rho])
    
    plt.bar(x_index+count*bar_width, C_cur_value, width=bar_width, edgecolor='black', label=r'$\lambda_1=$'+str(rho))
    count += 1
    
    
plt.xlabel('C')
plt.xticks( x_index + bar_width, C_list)
plt.ylabel('Average risk')
#plt.title("Average risks of outputs Tmdb risk averse peeling with C and "+r'$\lambda_1$')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig("tmdb_risk.png", bbox_inches='tight')
plt.savefig("tmdb_risk.pdf", bbox_inches='tight')
plt.show()

# %%
count = 1
for rho in rho_list:
    C_cur_value = []
    for C in C_list:
        C_cur_value.append(tmdb_size[C][rho])
    
    plt.bar(x_index+count*bar_width, C_cur_value, width=bar_width, edgecolor='black', label=r'$\lambda_1=$'+str(rho))
    count += 1
    
    
plt.xlabel('C')
plt.xticks( x_index + bar_width, C_list)
plt.ylabel('Log size (base 10)')
#plt.title("Sizes of outputs Tmdb risk averse peeling with C and "+r'$\lambda_1')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig("tmdb_size.png", bbox_inches='tight')
plt.savefig("tmdb_size.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# result plots for PPI datasets

# %%
import numpy as np
import matplotlib.pyplot as plt
def plot(ppi_result, filename):
    features = ['weight','risk']
    for feature in features:
        
#         C_list = [0.25,0.5,1,2,3,4,5,6]
        C_list = [1,2,3,4,5,6]
        x_index = np.arange(len(C_list))
        rho_list = [0.5,1,2]
        count = 1
        for rho in rho_list:
            C_cur_value = []
            for C in C_list:
                C_cur_value.append(ppi_result[feature][C][rho])

            plt.bar(x_index+count*bar_width, C_cur_value, width=bar_width, edgecolor='black', label=r'$\lambda_1=$'+str(rho))
            count += 1

        plt.xticks( x_index + bar_width, C_list)
        plt.xlabel('C')
        plt.ylabel('Average '+feature)
        #plt.title("Average "+feature+"s of outputs from PPI "+filename+" dataset")
        plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
        plt.tight_layout()
        plt.savefig(filename+"_"+feature+".jpg", bbox_inches='tight')
        plt.savefig(filename+"_"+feature+".pdf", bbox_inches='tight')
        plt.show()
    
    feature = 'Size'
    C_list = [1,2,3,4,5,6]
    x_index = np.arange(len(C_list))
    rho_list = [0.5,1,2]
    count = 1
    for rho in rho_list:
        C_cur_value = []
        for C in C_list:
            C_cur_value.append(ppi_result['size'][C][rho])

        plt.bar(x_index+count*bar_width, C_cur_value, width=bar_width, edgecolor='black', label=r'$\lambda_1=$'+str(rho))
        count += 1

    plt.xticks( x_index + bar_width, C_list)
    plt.xlabel('C')
    plt.ylabel(feature)
    #plt.title(feature+"s of outputs from PPI "+filename+" dataset")
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.tight_layout()
    plt.savefig(filename+"_"+feature+".jpg", bbox_inches='tight')
    plt.savefig(filename+"_"+feature+".pdf", bbox_inches='tight')
    plt.show()

# %%
biogrid_yeast_physical_unweighted_result = {'risk': {0.25: {0.5: 0.12295423183759525, 1: 0.12295423183759382, 2: 0.052137185021836965, 10: 0.008785586161879426}, 0.5: {0.5: 0.12295423183760354, 1: 0.1229542318376028, 2: 0.052197607391923445, 10: 0.008815885270135243}, 1: {0.5: 0.12499999997808253, 1: 0.12499999999591496, 2: 0.11083333333676904, 10: 1.3540741985544962e-11}, 2: {0.5: 0.1250000000404139, 1: 0.12500000000641853, 2: 0.10701626141486467, 10: -5.084798079662043e-12}, 3: {0.5: 0.12500000002754463, 1: 0.12500000000818035, 2: 0.10701626141504572, 10: -1.908144140776716e-12}, 4: {0.5: 0.12500000000235523, 1: 0.1249999999979935, 2: 0.10701626141402154, 10: -5.779673036456554e-12}, 5: {0.5: 0.1249999999693292, 1: 0.12499999998123279, 2: 0.1070162614122564, 10: -1.2301361743286303e-11}, 6: {0.5: 0.12499999999302402, 1: 0.12499999999338196, 2: 0.1070162614134823, 10: -7.956211960437245e-12}}, 
'weight': {0.25: {0.5: 0.12696761725186123, 1: 0.1269676172518555, 2: 0.054963044030891146, 10: 0.00920643248716174}, 0.5: {0.5: 0.12696761725186576, 1: 0.12696761725186428, 2: 0.05510319708715434, 10: 0.009383464058353202}, 1: {0.5: 0.24999999997806113, 1: 0.24999999999589356, 2: 0.17000000000343227, 10: 1.3455143790346362e-11}, 2: {0.5: 0.2500000000244182, 1: 0.2500000000074205, 2: 0.16622807017682903, 10: 1.4302570823596629e-11}, 3: {0.5: 0.2500000000157792, 1: 0.2500000000093245, 2: 0.16622807017718394, 10: 2.575469339709748e-11}, 4: {0.5: 0.2499999999991594, 1: 0.24999999999806896, 2: 0.166228070175216, 10: -7.162566835933695e-12}, 5: {0.5: 0.24999999997721029, 1: 0.249999999979591, 2: 0.1662280701718051, 10: -6.908253561036365e-11}, 6: {0.5: 0.2499999999929494, 1: 0.24999999999300904, 2: 0.16622807017421337, 10: -2.487786248192776e-11}}, 
'size': {0.25: {0.5: 5639, 1: 5639, 2: 4695, 10: 3510}, 
0.5: {0.5: 5639, 1: 5639, 2: 4695, 10: 3503}, 
1: {0.5: 4, 1: 4, 2: 25, 10: 1}, 
2: {0.5: 4, 1: 4, 2: 20, 10: 1}, 
3: {0.5: 4, 1: 4, 2: 20, 10: 1}, 
4: {0.5: 4, 1: 4, 2: 20, 10: 1}, 
5: {0.5: 4, 1: 4, 2: 20, 10: 1}, 
6: {0.5: 4, 1: 4, 2: 20, 10: 1}}}
plot(biogrid_yeast_physical_unweighted_result,"biogrid_yeast_physical_unweighted")

# %%
collins2007_result = {'risk': {0.25: {0.5: 0.16206960872939508, 1: 0.16206960872939508, 2: 0.0030408008874227904, 10: 0.0021341517876478817}, 0.5: {0.5: 0.1620696087293954, 1: 0.16206960872939546, 2: 0.01743442387380593, 10: 0.0019842534013560136}, 1: {0.5: 0.1270244999998266, 1: 0.12857798529429293, 2: 0.12331771323535, 10: -2.2452842054723207e-12}, 2: {0.5: 0.21140824691402638, 1: 0.1573408643790702, 2: 6.603922308617028e-14, 10: -1.0192197962793796e-12}, 3: {0.5: 0.21140824691407722, 1: 0.1783648908428732, 2: 8.968269940674972e-13, 10: -9.302443872667714e-13}, 4: {0.5: 0.21140824691319482, 1: 0.19100807509428852, 2: -9.045062072166694e-13, 10: -1.1682620682806246e-12}, 5: {0.5: 0.2114082469137326, 1: 0.19563761076922814, 2: 3.449958743010654e-13, 10: -1.1296942737094838e-14}, 6: {0.5: 0.21140824691375193, 1: 0.19899044820513012, 2: 4.534230599615548e-13, 10: 2.398329202300253e-14}}, 'weight': {0.25: {0.5: 0.18669028913214125, 1: 0.18669028913214114, 2: 0.003153584833895599, 10: 0.0022189946615340742}, 0.5: {0.5: 0.18669028913214147, 1: 0.18669028913214153, 2: 0.03193061142341266, 10: 0.0039685068027073035}, 1: {0.5: 0.2540489999998513, 1: 0.2571559705884382, 2: 0.24340013235301086, 10: -1.7756043549046482e-12}, 2: {0.5: 0.3171123703705488, 1: 0.2727997352941024, 2: -3.68548056463834e-13, 10: -9.11177566146609e-13}, 3: {0.5: 0.3171123703706438, 1: 0.26644127216118696, 2: 1.2697213440880692e-12, 10: 6.606975503099798e-13}, 4: {0.5: 0.31711237037004747, 1: 0.279791501886741, 2: -2.2646070473184173e-12, 10: -2.330546012584406e-12}, 5: {0.5: 0.3171123703704104, 1: 0.28625839487179683, 2: 1.5524129941309523e-13, 10: 8.39827360054632e-14}, 6: {0.5: 0.31711237037042567, 1: 0.2898146307692403, 2: 3.1582277252247633e-13, 10: 2.4424947786605096e-13}}, 'size': {0.25: {0.5: 1391, 1: 1391, 2: 544, 10: 532}, 0.5: {0.5: 1391, 1: 1391, 2: 573, 10: 147}, 1: {0.5: 19, 1: 17, 2: 34, 10: 1}, 2: {0.5: 9, 1: 51, 2: 1, 10: 1}, 3: {0.5: 9, 1: 91, 2: 1, 10: 1}, 4: {0.5: 9, 1: 53, 2: 1, 10: 1}, 5: {0.5: 9, 1: 39, 2: 1, 10: 1}, 6: {0.5: 9, 1: 26, 2: 1, 10: 1}}}
plot(collins2007_result,"collins2007")

# %%
gavin2006_socioaffinities_rescaled_result = {'risk': {0.25: {0.5: 0.0744517199402084, 1: 0.07445171994020841, 2: 0.0031559636062679208, 10: -1.4304842033119587e-12}, 0.5: {0.5: 0.07446803390014417, 1: 0.0744680339001442, 2: 0.0062782753165260725, 10: -1.088704701476892e-12}, 1: {0.5: 0.09566487499970408, 1: 0.08469210000016009, 2: 0.06598145430106966, 10: -2.708975019613501e-13}, 2: {0.5: 0.09566487499651327, 1: 0.08469209999987282, 2: 0.07699281818176476, 10: 8.390728024487689e-13}, 3: {0.5: 0.09566487499990117, 1: 0.0896448750000256, 2: 0.07683846428571739, 10: 7.165539138782595e-13}, 4: {0.5: 0.09566487499993837, 1: 0.08964487500003182, 2: 0.07683846428572338, 10: 7.705580675962805e-13}, 5: {0.5: 0.09566487499946408, 1: 0.0925433124999312, 2: 0.07403464999996301, 10: 7.634472085499958e-13}, 6: {0.5: 0.0956648749997322, 1: 0.09254331249999148, 2: 0.07403464999998455, 10: 8.632703002606697e-13}}, 'weight': {0.25: {0.5: 0.08381545346340659, 1: 0.08381545346340662, 2: 0.003404723147628179, 10: -6.576149347288334e-12}, 0.5: {0.5: 0.08386658771354069, 1: 0.08386658771354075, 2: 0.009636506665769456, 10: -2.2620574033684175e-12}, 1: {0.5: 0.19132974999973149, 1: 0.16938420000016557, 2: 0.12889449999999616, 10: -2.1608024012048302e-13}, 2: {0.5: 0.19132974999788518, 1: 0.16938419999986212, 2: 0.15398563636354212, 10: -3.2336933570353904e-13}, 3: {0.5: 0.19132975000001468, 1: 0.1792897500000244, 2: 0.15367692857144322, 10: 3.3410844013892495e-13}, 4: {0.5: 0.1913297500000548, 1: 0.17928975000003136, 2: 0.1536769285714509, 10: 3.3308272951415244e-13}, 5: {0.5: 0.1913297499997632, 1: 0.18508662499992143, 2: 0.14806929999994076, 10: -1.0648102115849737e-13}, 6: {0.5: 0.19132974999993044, 1: 0.1850866249999861, 2: 0.14806929999998744, 10: 9.399236213695459e-14}}, 'size': {0.25: {0.5: 1808, 1: 1808, 2: 805, 10: 1}, 0.5: {0.5: 1808, 1: 1808, 2: 826, 10: 1}, 1: {0.5: 2, 1: 10, 2: 31, 10: 1}, 2: {0.5: 2, 1: 10, 2: 11, 10: 1}, 3: {0.5: 2, 1: 6, 2: 7, 10: 1}, 4: {0.5: 2, 1: 6, 2: 7, 10: 1}, 5: {0.5: 2, 1: 4, 2: 5, 10: 1}, 6: {0.5: 2, 1: 4, 2: 5, 10: 1}}}
plot(gavin2006_socioaffinities_rescaled_result,"gavin2006_socioaffinities_rescaled")

# %%
krogan2006_core_result = {'risk': {0.25: {0.5: 0.10308336861204137, 1: 0.1030833686120414, 2: 0.0042134402488868536, 10: -2.1061740314729407e-13}, 0.5: {0.5: 0.10308336861204165, 1: 0.10032636594704603, 2: 0.013487347432158013, 10: -2.0423003566060293e-12}, 1: {0.5: 0.12692857142848576, 1: 0.11995198902609837, 2: 0.10952614379085734, 10: -3.3192029371900144e-12}, 2: {0.5: 0.13298976608173052, 1: 0.13443018518516414, 2: 3.2074075221525686e-14, 10: -2.446351503918991e-14}, 3: {0.5: 0.20370370370289204, 1: 0.13443018518517036, 2: 1.4191391599763465e-13, 10: 2.4796589250659008e-14}, 4: {0.5: 0.203703703704329, 1: 0.134430185185202, 2: 9.36597796400245e-13, 10: 2.714895082463863e-13}, 5: {0.5: 0.2037037037025895, 1: 0.13443018518515792, 2: -3.8187212331532095e-13, 10: 2.332491754037574e-14}, 6: {0.5: 0.2037037037055911, 1: 0.13540191570886484, 2: 1.9769338417961276e-12, 10: 4.271439393128196e-13}}, 'weight': {0.25: {0.5: 0.12292984795054318, 1: 0.12292984795054328, 2: 0.005508842238763406, 10: 8.43522705388731e-12}, 0.5: {0.5: 0.12292984795054335, 1: 0.12021015840776077, 2: 0.02400844046577011, 10: -7.659879674988066e-12}, 1: {0.5: 0.25385714285707245, 1: 0.23613168724284025, 2: 0.21648459383754723, 10: -2.7861293519162455e-12}, 2: {0.5: 0.2579385964911436, 1: 0.2519277777777583, 2: -5.156487688822246e-13, 10: -5.439175640125824e-13}, 3: {0.5: 0.30555555555512715, 1: 0.251927777777765, 2: -4.2624248877090524e-13, 10: -4.652815976865638e-13}, 4: {0.5: 0.3055555555560469, 1: 0.2519277777777988, 2: 1.2394008867469093e-12, 10: 1.0731238147084446e-12}, 5: {0.5: 0.3055555555548964, 1: 0.25192777777775044, 2: -1.3852385528541538e-12, 10: -1.3041991446830144e-12}, 6: {0.5: 0.30555555555687824, 1: 0.25328735632189986, 2: 3.353884522448231e-12, 10: 3.09558620536768e-12}}, 'size': {0.25: {0.5: 2621, 1: 2621, 2: 1607, 10: 1}, 0.5: {0.5: 2621, 1: 2606, 2: 1674, 10: 1}, 1: {0.5: 35, 1: 81, 2: 119, 10: 1}, 2: {0.5: 38, 1: 60, 2: 1, 10: 1}, 3: {0.5: 3, 1: 60, 2: 1, 10: 1}, 4: {0.5: 3, 1: 60, 2: 1, 10: 1}, 5: {0.5: 3, 1: 60, 2: 1, 10: 1}, 6: {0.5: 3, 1: 58, 2: 1, 10: 1}}}
plot(krogan2006_core_result,"krogan2006_core")

# %%
krogan2006_extended_result = {'risk': {0.25: {0.5: 0.05569856853015845, 1: 0.055698568530158477, 2: 0.00341642742333849, 10: 0.0021999840291284027}, 0.5: {0.5: 0.05569856853015847, 1: 0.055698568530158546, 2: 0.005361821511392151, 10: 0.0024005477402960847}, 1: {0.5: 0.1237499999996747, 1: 0.11763157894747465, 2: 0.09127906976748533, 10: 3.504184135360288e-12}, 2: {0.5: 0.12375000000104291, 1: 0.11763157894750564, 2: 0.10687500000005984, 10: -4.66515714947435e-13}, 3: {0.5: 0.12374999999943093, 1: 0.11763157894728626, 2: 0.11174999999997337, 10: -7.153817768052788e-13}, 4: {0.5: 0.12375000000002001, 1: 0.12117647058826375, 2: 0.11444444444447, 10: -5.478694421211132e-13}, 5: {0.5: 0.123749999999764, 1: 0.12117647058820125, 2: 0.11444444444444057, 10: -6.088553697494646e-13}, 6: {0.5: 0.12374999999955727, 1: 0.12117647058814685, 2: 0.11444444444441415, 10: -6.499509028906535e-13}}, 'weight': {0.25: {0.5: 0.062095208764981126, 1: 0.062095208764981216, 2: 0.003909068468433512, 10: 0.0025254882859653783}, 0.5: {0.5: 0.06209520876498113, 1: 0.06209520876498129, 2: 0.0077926330335526236, 10: 0.004456974319856548}, 1: {0.5: 0.24749999999969527, 1: 0.23526315789485172, 2: 0.18000000000004726, 10: 3.668663676458505e-12}, 2: {0.5: 0.24750000000072708, 1: 0.23526315789489202, 2: 0.21375000000009844, 10: 1.411759598113377e-12}, 3: {0.5: 0.24749999999966463, 1: 0.23526315789464813, 2: 0.22349999999993286, 10: -1.4037506789149906e-12}, 4: {0.5: 0.24750000000006137, 1: 0.24235294117650424, 2: 0.22888888888892034, 10: 3.140052320724603e-13}, 5: {0.5: 0.24749999999989195, 1: 0.24235294117643516, 2: 0.22888888888886114, 10: -6.084928479455615e-13}, 6: {0.5: 0.24749999999975547, 1: 0.24235294117637549, 2: 0.22888888888880793, 10: -1.4741955302439514e-12}}, 'size': {0.25: {0.5: 3653, 1: 3653, 2: 2527, 10: 2451}, 0.5: {0.5: 3653, 1: 3653, 2: 2559, 10: 2319}, 1: {0.5: 8, 1: 19, 2: 43, 10: 1}, 2: {0.5: 8, 1: 19, 2: 24, 10: 1}, 3: {0.5: 8, 1: 19, 2: 20, 10: 1}, 4: {0.5: 8, 1: 17, 2: 18, 10: 1}, 5: {0.5: 8, 1: 17, 2: 18, 10: 1}, 6: {0.5: 8, 1: 17, 2: 18, 10: 1}}}
plot(krogan2006_extended_result,"krogan2006_extended")
